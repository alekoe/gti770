# %% [markdown]
# # GTI770 - Systèmes Intelligents et Apprentissage Machine
# #### Alessandro L. Koerich
# ## Notebook Jupyter - 2_FindPixelRGB
# ### Simpsons Dataset
# ##### January 2019

# %%
# Imports General
import numpy as np
import matplotlib.pyplot as plt
import os
import sys
import time
import matplotlib

# %%
# Imports Scikit-Learn
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import normalize
from sklearn.preprocessing import scale
from sklearn.preprocessing import MinMaxScaler

# %%
#Imports from TP1 GTI770-H2018
import csv
import math
import scipy.ndimage as nd
from scipy.stats.mstats import mquantiles, kurtosis, skew
from sklearn.preprocessing import LabelEncoder

# %%
import cv2

# %%
# Load image to analyze
if os.path.isfile("Simpsons-Train-Valid/Train/bart001.bmp"):
    img_color = cv2.imread('Simpsons-Train-Valid/Train/bart001.bmp',-1)
else:
    print ("The file does not exist.")

height, width, channels = img_color.shape
print (height, width, channels)
# Out:
# 497 326 3

# %%
RGB_img = cv2.cvtColor(img_color, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_img)
plt.title('my picture')
plt.show()

# %%
print("pixel at (x = 150, y = 300) [R,G,B]:\t[%i,%i,%i]" % tuple(RGB_img[300,150,:]))
print ("data-type: %s " % RGB_img.dtype)
# Out:
# pixel at (x = 150, y = 300) [R,G,B]:	[247,99,16]
# data-type: uint8

# %%
plt.title('my picture')
plt.imshow(RGB_img)
plt.xlim(150, 151)
plt.ylim(300, 301)
plt.show()
print("pixel at ( x = 150, y = 300) [R,G,B]:\t[%i,%i,%i]" % tuple(RGB_img[300,150,:]))
print ("data-type: %s " % RGB_img.dtype)
# Out:
# pixel at ( x = 150, y = 300) [R,G,B]:	[247,99,16]
# data-type: uint8

# %%
# Load image to analyze
if os.path.isfile("Simpsons-Train-Valid/Train/homer001.bmp"):
    img_color = cv2.imread('Simpsons-Train-Valid/Train/homer001.bmp',-1)
else:
    print ("The file does not exist.")

height, width, channels = img_color.shape
print (height, width, channels)
# Out:
# 576 237 3

# %%
RGB_img = cv2.cvtColor(img_color, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_img)
plt.title('my picture')
plt.show()

# %%
print("pixel at (x = 50, y = 450) [R,G,B]:\t[%i,%i,%i]" % tuple(RGB_img[450,50,:]))
print ("data-type: %s " % RGB_img.dtype)
# Out:
# pixel at (x = 50, y = 450) [R,G,B]:	[0,106,172]
# data-type: uint8

# %%
plt.title('my picture')
plt.imshow(RGB_img)
plt.xlim(50, 51)
plt.ylim(450, 451)
plt.show()
print("pixel at ( x = 150, y = 300) [R,G,B]:\t[%i,%i,%i]" % tuple(RGB_img[450,50,:]))
print ("data-type: %s " % RGB_img.dtype)
# Out:
# pixel at ( x = 150, y = 300) [R,G,B]:	[0,106,172]
# data-type: uint8
